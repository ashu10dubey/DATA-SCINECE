# %% [markdown]
# #Q1. Explain why we have to use the Exception class while creating a Custom Exception.
# Note: Here Exception class refers to the base class for all the exceptions.
# #Q2. Write a python program to print Python Exception Hierarchy.
# #Q3. What errors are defined in the ArithmeticError class? Explain any two with an example.
# #Q4. Why LookupError class is used? Explain with an example KeyError and IndexError.
# #Q5. Explain ImportError. What is ModuleNotFoundError?
# #Q6. List down some best practices for exception handling in python.

# %%
# Q1: Why use Exception class while creating Custom Exceptions
# Custom exceptions should inherit from the built-in Exception class
# because it ensures the new exception behaves like a standard exception.
# It allows using the exception handling mechanism (try-except) effectively.

class CustomError(Exception):  # Inheriting from Exception
    def __init__(self, message):
        super().__init__(message)

try:
    raise CustomError("This is a custom exception!")
except CustomError as e:
    print(e)


# Q2: Python program to print Exception Hierarchy
import sys

def print_exception_hierarchy(base, level=0):
    print(" " * level * 4 + f"{base.__name__}")
    for subclass in base.__subclasses__():
        print_exception_hierarchy(subclass, level + 1)

print_exception_hierarchy(BaseException)


# Q3: ArithmeticError class and its exceptions
# ArithmeticError is a base class for exceptions like ZeroDivisionError and OverflowError.

# Example 1: ZeroDivisionError
try:
    result = 10 / 0  # Division by zero
except ZeroDivisionError as e:
    print("ZeroDivisionError occurred:", e)

# Example 2: OverflowError
import math
try:
    print(math.exp(1000))  # Exponential of a large number
except OverflowError as e:
    print("OverflowError occurred:", e)


# Q4: LookupError class and its exceptions (KeyError & IndexError)
# LookupError is a base class for exceptions like KeyError and IndexError.

# Example 1: KeyError
try:
    my_dict = {"a": 1, "b": 2}
    print(my_dict["c"])  # Key does not exist
except KeyError as e:
    print("KeyError occurred:", e)

# Example 2: IndexError
try:
    my_list = [1, 2, 3]
    print(my_list[5])  # Index out of range
except IndexError as e:
    print("IndexError occurred:", e)


# Q5: ImportError and ModuleNotFoundError
# ImportError occurs when a module cannot be imported.
# ModuleNotFoundError is a subclass of ImportError, occurring when a module is not found.

try:
    import nonexistent_module  # This module does not exist
except ModuleNotFoundError as e:
    print("ModuleNotFoundError occurred:", e)


# Q6: Best practices for exception handling in Python
# 1. Catch specific exceptions instead of using a generic 'except' block.
# 2. Use the 'finally' block to release resources.
# 3. Avoid bare except statements; always specify the exception type.
# 4. Use 'with' statement for file operations to ensure automatic closing.
# 5. Log exceptions instead of printing them in production code.
# 6. Raise exceptions with clear messages to help debugging.

try:
    with open("nonexistent_file.txt", "r") as file:
        content = file.read()
except FileNotFoundError as e:
    print("FileNotFoundError occurred:", e)
finally:
    print("Execution completed.")
# Out:
# This is a custom exception!
# BaseException
#     BaseExceptionGroup
#         ExceptionGroup
#     Exception
#         ArithmeticError
#             FloatingPointError
#             OverflowError
#             ZeroDivisionError
#                 DivisionByZero
#                 DivisionUndefined
#             DecimalException
#                 Clamped
#                 Rounded
#                     Underflow
#                     Overflow
#                 Inexact
#                     Underflow
#                     Overflow
#                 Subnormal
#                     Underflow
#                 DivisionByZero
#                 FloatOperation
#                 InvalidOperation
#                     ConversionSyntax
#                     DivisionImpossible
#                     DivisionUndefined
#                     InvalidContext
#         AssertionError
#         AttributeError
#             FrozenInstanceError
#         BufferError
#         EOFError
# ...
